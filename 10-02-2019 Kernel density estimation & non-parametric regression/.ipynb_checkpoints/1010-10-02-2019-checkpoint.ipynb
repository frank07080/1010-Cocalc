# %% [markdown]
# ## Kernel density estimation & non-parametric regression
#
# #### *2 October 2019*
# #### *DATA 1010*
#
# <img src="tricube-100.svg" style="float: right; width: 250px">
#
# We want to estimate the joint probability density function $f(x,y)$ of two random variables $X$ and $Y$, based on a given set of observations $\{X_i,Y_i\}_{i=1}^n$. The key idea for **kernel density estimation** is to spread out a $1/n$ probability mass around each observation. In mathematical terms, our estimator is
#
# $$\hat{f}_{\lambda}(x,y) = \frac{1}{n} \sum_{i=1}^n K_{\lambda}(x-X_i, y-Y_i)$$
#
# The *kernel* $K_\lambda$ is defined as a product $K_{\lambda}(x,y) = D_{\lambda}(x)D_{\lambda}(y)$.

# %% [markdown]
# ![](images/0.PNG)

# %% [markdown]
# ![](images/0a.PNG)

# %% [markdown]
# ![](images/0b.PNG)

# %% [markdown]
# ### Problem 1
#
# Suppose that $D_\lambda: \mathbb{R} \to \mathbb{R}$ is a function whose support is equal to $[-\lambda,\lambda]$. What is the support of $K_\lambda(x,y) = D_\lambda(x)D_\lambda(y)$?
#
# (Note: the support of a function is the set of all points where the function is nonzero, together with the boundary of that set.)

# %% [markdown]
# *Solution:*
# The suppport of $K_\lambda$ is $[-\lambda, \lambda]^2$

# %% [markdown]
# ---
#
# It usually doesn't matter too much what the shape of our kernel is. Let's use the *tricube* function:
#
# $$D(u) = \frac{70}{81} ( 1 - |u|^3)^3 \boldsymbol{1}_{|u|\leq 1}.$$
#
# Some other functions used include the Normal density and the triangular function:
#
# $$ D(u) =  \frac{1}{\sqrt{2\pi}}e^{-\frac{u^2}{2}}, \quad D(u) = (1 - |u|)\boldsymbol{1}_{|u|\leq 1}.$$
#
# ### Problem 2 (Use Gaussian Function as Kernel, and see what KDF looks like)
#
# Write a Julia function to estimation joint probability density $\hat{f}_{\lambda}(x,y)$ using the Normal function. Plot your result. Experiment with various values of $\lambda$.

# %%
import Pkg; Pkg.add("LaTeXStrings")
using LinearAlgebra, Statistics, Roots, Optim, Plots, Random, Distributions
# Out:
#  Resolving package versions...
#   Updating `/opt/julia/environments/v1.2/Project.toml`
#  [no changes]
#   Updating `/opt/julia/environments/v1.2/Manifest.toml`
#  [no changes]

# %%
Random.seed!(1234)

function kdenorm(samples, λ)
    # fill in the blanks and uncomment
    D(u) = exp(-u^2/2)/√(2π)
    D(λ,u) = 1/λ * D(u/λ)
    K(λ,x,y) = D(λ,x) * D(λ,y)
    kde(λ,x,y,samples) = sum(K(λ,x-Xi,y-Yi) for (Xi,Yi) in samples)/length(samples)
    
    scatter(samples, markerstrokewidth=0, markersize=2, label = "",
            color = :DarkRed)
    heatmap!(0:0.1:20, -2:0.1:12, (x,y) -> kde(λ,x,y,samples), 
             opacity = 0.5, color = cgrad([:white, :MidnightBlue, :Gold]))
end


# True regression function
r(x) = 2 + 1/50*x*(30-x) # represent the score you will get after studying x hours on average

# True density function
σy = 3/2  
f(x,y) = 3/4000 * 1/√(2π*σy^2) * x*(20-x)*exp(-1/(2σy^2)*(y-r(x))^2)

# F(t) is the CDF of X
F(t) = -t^3/4000 + 3t^2/400

# Sample from the distribution of X (inverse CDF trick)
function sampleX()
    U = rand()
    find_zero(t->F(t)-U,(0,20),Bisection())
end

# Sample from joint distribution of X and Y
function sampleXY(r, σ)
    X = sampleX()
    Y = r(X) + σ*randn()
    (X,Y)
end

n = 1000 # number of samples to draw

# Sample n observations
samples = [sampleXY(r,σy) for i=1:n]

# Estimate density
kdenorm(samples, 1) # 1 is representing lambda, 1 or 2 is good

# %%
kdenorm(samples, 0.1) # lambda too small is bad, cause it is seperating each data point

# %%
kdenorm(samples, 10) # probability mass spread out too much

# %% [markdown]
# ---
#
# # Hyperparameter Choosing - $\lambda$

# %% [markdown]
# You might have been able to choose a favorite $\lambda$ in this exercise by looking at the plots. But clearly we are going to want a better approach.
#
# To find the optimal value of $\lambda$, we minimize the mean integrated squared error (MISE): $\int (\hat{f}_\lambda - f)^2$.
#
# Expanding, we realize that this amounts to minimizing: $\int \hat{f}^2_{\lambda} -2 \int \hat{f}_{\lambda}f $

# %% [markdown]
# ![](images/2.PNG)

# %% [markdown]
# ![](images/2d.PNG)

# %% [markdown]
# This can be estimated from data $(X_i,Y_i)_{i=1}^{n}$:
# $$ \hat{J}(\lambda) = \int \hat{f}^2_{\lambda} - \frac{2}{n}\sum_{i=1}^n \hat{f}_{\lambda}^{(-i)}(X_i,Y_i),$$
#
# where $\hat{f}_{\lambda}^{(-i)}$ is the estimator obtained from the original data set with the $i$th observation removed（只看其他的点）.

# %% [markdown]
# ![](images/2a.PNG)

# %% [markdown]
# ![](images/2b.PNG)

# %% [markdown]
# ![](images/2c.PNG)

# %% [markdown]
# ## Problem 3
#
# Suppose that $f$ is the standard normal density on $\mathbb{R}$, and $\widehat{f}$ is the kernel density estimator based on the tricube kernel with $\lambda = 1$. Compare $\int \widehat{f} f$ to $\frac{1}{n}\sum_{i=1}^n \widehat{f}^{(-i)}(X_i)$, where $X_1, \ldots, X_{n}$ are independent random variables with distribution given by $f$.
#
# Experiment with different values of $n$ and $\lambda$.

# %%
using LaTeXStrings, Random; Random.seed!(123)

#n = 10 # for small number of observations
n = 10_000
λ = 0.4 # lambda for 0.4 at large number of observation is good, otherwise 1 is good
X = randn(n)

tricube(x) = abs(x) ≤ 1 ? 70/81 * (1-abs(x)^3)^3 : 0
tricube(λ, x) = tricube(x/λ)/λ
f̂(λ,X,x) = mean(tricube(λ,x-xi) for xi in X)
f̂(λ,X,i,x) = mean(tricube(λ,x-X[j]) for j in eachindex(X) if j != i) # leave one out term (not used)
f(x) = pdf(Normal(0,1), x)

plot(-3:0.01:3, f, label = "true density")
plot!(-3:0.01:3, x -> f̂(λ,X,x), label = L"\widehat{f}_{\lambda}")

# %% [markdown]
# Then we compare the two terms:

# %%
# summing area for calculating the integral
𝑎 = 0.001
sum(f̂(λ,X,x)*f(x) for x in -10:𝑎:10)*𝑎
# Out:
# 0.27917028743427047

# %%
# leave one out sum
mean(f̂(λ,X,i,X[i]) for i=eachindex(X))
# Out:
# 0.27777224202853656

# %%
# Not leave one out version is ok when lambda is chosen to be a large value
# when lambda is chosen to be 0.001, this term will be way larger then the leave one out sum
mean(f̂(λ,X,X[i]) for i=eachindex(X))
# Out:
# 0.27796051418705126

# %% [markdown]
# ---
#
# ## Non-parametric regression
#
# Next, we estimate the regression function $r(x) = \mathbb{E}[Y | X = x]$ by integration the estimate for the conditional density $\hat{f}_{Y | X=x}(x)$.
#
# Note that:
# $ \hat{f}_{Y|X=x} = \frac{\hat{f}(x,y)}{\int \hat{f}(x,y) dy} $ and $r(x) = \int y \hat{f}_{Y|X=x}(x) $
#
# Substituting the formula for our estimate $\hat{f}$, we find that:
#
# $$ \hat{r}(x) = \frac{\sum_{i=1}^n D_{\lambda}(x-X_i)Y_i}{\sum_{i=1}^n D_{\lambda}(x-X_i)}.$$
#
# ### Problem 4
#
# (a) Plot the regression function using various values of $\lambda$.
#
# (b) What tradeoffs do you notice when $\lambda$ is increased or decreased?
#
# (c) What's the smallest integrated squared error you can come up with?

# %%
λ = 2.0
# r̂(λ,x) = Nadaraya-Watson estimator
plot(0:0.01:20, x->r̂(λ,x), label = "Nadaraya-Watson estimator", ylims = (0,10), linewidth = 2, color = :Red)
plot!(0:0.2:20, r, label = "actual regression function", linewidth = 2, color = :MidnightBlue)
# Out:
# UndefVarError: r̂ not defined
#
# Stacktrace:
#  [1] (::getfield(Main, Symbol("##18#19")))(::Float64) at ./In[6]:3
#  [2] iterate at ./generator.jl:47 [inlined]
#  [3] _collect(::Array{Float64,1}, ::Base.Generator{Array{Float64,1},getfield(Main, Symbol("##18#19"))}, ::Base.EltypeUnknown, ::Base.HasShape{1}) at ./array.jl:619
#  [4] collect_similar(::Array{Float64,1}, ::Base.Generator{Array{Float64,1},getfield(Main, Symbol("##18#19"))}) at ./array.jl:548
#  [5] map(::Function, ::Array{Float64,1}) at ./abstractarray.jl:2073
#  [6] compute_y at /opt/julia/packages/Plots/h3o4c/src/series.jl:80 [inlined]
#  [7] compute_xyz(::Array{Float64,1}, ::Function, ::Nothing) at /opt/julia/packages/Plots/h3o4c/src/series.jl:94
#  [8] apply_recipe(::Dict{Symbol,Any}, ::Type{Plots.SliceIt}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::Function, ::Nothing) at /opt/julia/packages/Plots/h3o4c/src/series.jl:152
#  [9] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},getfield(Main, Symbol("##18#19"))}) at /opt/julia/packages/Plots/h3o4c/src/pipeline.jl:83
#  [10] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},getfield(Main, Symbol("##18#19"))}) at /opt/julia/packages/Plots/h3o4c/src/plot.jl:178
#  [11] #plot#133(::Base.Iterators.Pairs{Symbol,Any,NTuple{4,Symbol},NamedTuple{(:label, :ylims, :linewidth, :color),Tuple{String,Tuple{Int64,Int64},Int64,Symbol}}}, ::typeof(plot), ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::Vararg{Any,N} where N) at /opt/julia/packages/Plots/h3o4c/src/plot.jl:57
#  [12] (::getfield(RecipesBase, Symbol("#kw##plot")))(::NamedTuple{(:label, :ylims, :linewidth, :color),Tuple{String,Tuple{Int64,Int64},Int64,Symbol}}, ::typeof(plot), ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::Function) at ./none:0
#  [13] top-level scope at In[6]:2

# %%
# ISE_error = approximate squared error between r(x) and r̂(x)

# %% [markdown]
# ---
#
# ### Problem 5 (Challenge)
#
# We tackle the problem of estimating the variance for our regression estimate $\hat{r}(x)$.
#
# Suppose, $Y_i = \hat{r}(X_i) + \epsilon_i$
#
# In expectation, the error term is $0$, i.e. $\mathbb{E}[\epsilon_i | X_i] = 0$
#
# Lets assume a variance function $\sigma^2$ such that:
# $$ \epsilon_i^2 = \sigma^2(X_i) + \eta_i $$
#
# where $\mathbb{E}[\eta_i | X_i] = 0$
#
# Write Julia code to compute the squared error $\epsilon_i^2$ at each point $(X_i,Y_i)$ and estimate the function $\sigma^2$ using KDE. Plot $\hat{r}(x)$ and a $95\%$ shaded confidence region between $\hat{r}(x) - 1.96\hat{\sigma}(x)$ and $\hat{r}(x) + 1.96\hat{\sigma}(x)$.
